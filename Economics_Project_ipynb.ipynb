# %% [markdown]
# <a href="https://colab.research.google.com/github/Suryaprasadindra/Economics-Project/blob/main/Economics_Project_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ** 📊 Data Analytics 🎯 Project for analysing pay & employment of Manufacturing-private ownership**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/all_counties_Manufacturing.csv')

# %%
df.head()
# Out:
#   area_fips  own_code  industry_code  agglvl_code  size_code  year qtr  \
# 0     01000         3           1013           53          0  2023   A
# 1     01000         5           1013           53          0  2023   A
# 2     01001         5           1013           73          0  2023   A
# 3     01003         5           1013           73          0  2023   A
# 4     01005         5           1013           73          0  2023   A
#
#   disclosure_code  annual_avg_estabs  annual_avg_emplvl  ...  \
# 0               N                  3                  0  ...
# 1             NaN               6838             280961  ...
# 2             NaN                 36               1520  ...
# 3             NaN                268               4089  ...
# 4             NaN                 27               2064  ...
#
#    oty_total_annual_wages_chg  oty_total_annual_wages_pct_chg  \
# 0                           0                             0.0
# ...

# %%
df.columns
# Out:
# Index(['area_fips', 'own_code', 'industry_code', 'agglvl_code', 'size_code',
#        'year', 'qtr', 'disclosure_code', 'annual_avg_estabs',
#        'annual_avg_emplvl', 'total_annual_wages', 'taxable_annual_wages',
#        'annual_contributions', 'annual_avg_wkly_wage', 'avg_annual_pay',
#        'lq_disclosure_code', 'lq_annual_avg_estabs', 'lq_annual_avg_emplvl',
#        'lq_total_annual_wages', 'lq_taxable_annual_wages',
#        'lq_annual_contributions', 'lq_annual_avg_wkly_wage',
#        'lq_avg_annual_pay', 'oty_disclosure_code', 'oty_annual_avg_estabs_chg',
#        'oty_annual_avg_estabs_pct_chg', 'oty_annual_avg_emplvl_chg',
#        'oty_annual_avg_emplvl_pct_chg', 'oty_total_annual_wages_chg',
#        'oty_total_annual_wages_pct_chg', 'oty_taxable_annual_wages_chg',
#        'oty_taxable_annual_wages_pct_chg', 'oty_annual_contributions_chg',
#        'oty_annual_contributions_pct_chg', 'oty_annual_avg_wkly_wage_chg',
# ...

# %%
df.dtypes
# Out:
# area_fips                            object
# own_code                              int64
# industry_code                         int64
# agglvl_code                           int64
# size_code                             int64
# year                                  int64
# qtr                                  object
# disclosure_code                      object
# annual_avg_estabs                     int64
# annual_avg_emplvl                     int64
# total_annual_wages                  float64
# taxable_annual_wages                float64
# annual_contributions                  int64
# annual_avg_wkly_wage                  int64
# avg_annual_pay                        int64
# lq_disclosure_code                   object
# lq_annual_avg_estabs                float64
# lq_annual_avg_emplvl                float64
# lq_total_annual_wages               float64
# lq_taxable_annual_wages             float64
# lq_annual_contributions             float64
# ...

# %%
df.isnull().sum()
# Out:
# area_fips                              0
# own_code                               0
# industry_code                          0
# agglvl_code                            0
# size_code                              0
# year                                   0
# qtr                                    0
# disclosure_code                     3447
# annual_avg_estabs                      0
# annual_avg_emplvl                      0
# total_annual_wages                     0
# taxable_annual_wages                   0
# annual_contributions                   0
# annual_avg_wkly_wage                   0
# avg_annual_pay                         0
# lq_disclosure_code                  3419
# lq_annual_avg_estabs                   0
# lq_annual_avg_emplvl                   0
# lq_total_annual_wages                  0
# lq_taxable_annual_wages                0
# lq_annual_contributions                0
# lq_annual_avg_wkly_wage                0
# lq_avg_annual_pay                      0
# ...

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # **top 3 avg_annual_pay in ALL state's counties**

# %%
# Convert 'area_fips' to string if it's not already
df['area_fips'] = df['area_fips'].astype(str)

# Select top 3 counties based on avg_annual_pay in all counties
top_3_avg_pay = df.nlargest(3, 'avg_annual_pay')
top_3_avg_pay[['area_fips','avg_annual_pay']]
# Out:
#      area_fips  avg_annual_pay
# 1283     24009          307208
# 250      06085          302214
# 3776     C4194          297929

# %%
# Data for the bar chart
county_names = ['Calvert County, MD', 'Santa Clara County, CA', 'San Jose-Sunnyvale-Santa Clara, CA (MSA)']
avg_annual_pay = [307208, 302214, 297929]

# Create the bar chart
plt.figure(figsize=(12, 8))
bars = plt.bar(county_names, avg_annual_pay, color=['#4CAF50', '#2196F3', '#FF9800'])

# Add annotations on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.annotate(f'${height:,}',  # Format with commas
                 xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 5),  # Offset above bar
                 textcoords="offset points",
                 ha='center', va='bottom', fontsize=10, fontweight='bold')

# Title and labels
plt.title('Top 3 Counties/MSAs by Average Annual Pay in Manufacturing', fontsize=14, fontweight='bold')
plt.xlabel('County/MSA', fontsize=12)
plt.ylabel('Average Annual Pay ($)', fontsize=12)
plt.xticks(rotation=20)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # **top 3 avg_annual_pay in Kansas state's counties**

# %%
# Convert 'area_fips' to string if it's not already
df['area_fips'] = df['area_fips'].astype(str)

# Filter for Kansas counties (State FIPS code starts with '20')
df_kansas = df[df['area_fips'].str.startswith('20')]

# Display unique Kansas counties
unique_kansas_counties = df_kansas['area_fips'].unique()
print("Kansas County FIPS Codes:\n", unique_kansas_counties)
# Out:
# Kansas County FIPS Codes:
#  ['20000' '20001' '20003' '20005' '20007' '20009' '20011' '20013' '20015'
#  '20017' '20019' '20021' '20023' '20025' '20027' '20029' '20031' '20033'
#  '20035' '20037' '20039' '20041' '20043' '20045' '20047' '20049' '20051'
#  '20053' '20055' '20057' '20059' '20061' '20063' '20065' '20067' '20069'
#  '20071' '20073' '20075' '20077' '20079' '20081' '20083' '20085' '20087'
#  '20091' '20093' '20095' '20097' '20099' '20103' '20107' '20109' '20111'
#  '20113' '20115' '20117' '20119' '20121' '20123' '20125' '20127' '20129'
#  '20131' '20133' '20135' '20137' '20139' '20141' '20143' '20145' '20147'
#  '20149' '20151' '20153' '20155' '20157' '20159' '20161' '20163' '20165'
#  '20167' '20169' '20171' '20173' '20175' '20177' '20179' '20181' '20183'
#  '20185' '20187' '20189' '20191' '20193' '20195' '20197' '20199' '20201'
#  '20203' '20205' '20207' '20209' '20999']

# %%
# Display first few rows of the filtered DataFrame
df_kansas.head()
# Out:
#     area_fips  own_code  industry_code  agglvl_code  size_code  year qtr  \
# 961     20000         5           1013           53          0  2023   A
# 962     20001         5           1013           73          0  2023   A
# 963     20003         5           1013           73          0  2023   A
# 964     20005         5           1013           73          0  2023   A
# 965     20007         5           1013           73          0  2023   A
#
#     disclosure_code  annual_avg_estabs  annual_avg_emplvl  ...  \
# 961             NaN               3355             173226  ...
# 962             NaN                 21               1525  ...
# 963             NaN                 12                103  ...
# 964             NaN                 23                691  ...
# 965             NaN                  7                170  ...
#
#      oty_total_annual_wages_chg  oty_total_annual_wages_pct_chg  \
# 961                   687545367                             5.9
# ...

# %%
# Get the number of rows in the filtered DataFrame for Kansas counties
num_rows_kansas = len(df_kansas)
print(f"Number of rows for Kansas counties: {num_rows_kansas}")
# Out:
# Number of rows for Kansas counties: 104

# %%
# Select top 3 counties in entire kansas based on avg_annual_pay
top_3_avg_pay = df_kansas.nlargest(3, 'avg_annual_pay')
top_3_avg_pay[['area_fips','avg_annual_pay']]
# Out:
#      area_fips  avg_annual_pay
# 969      20015           86068
# 964      20005           85069
# 1006     20091           80555

# %% [markdown]
# *   **Butler County (FIPS: 20015)**
# *   **Atchison County (FIPS: 20005)**
# *   **Johnson County (FIPS: 20091)**

# %%
# Define a mapping of FIPS codes to county names
fips_to_county = {
    '20015': 'Butler County',
    '20005': 'Atchison County',
    '20091': 'Johnson County'
}

# Map FIPS codes to county names for y-axis labels
top_3_avg_pay['county_name'] = top_3_avg_pay['area_fips'].astype(str).map(fips_to_county)

# Sort data by average annual pay in descending order
top_3_avg_pay_sorted = top_3_avg_pay.sort_values(by='avg_annual_pay', ascending=False)

# Define colors for each bar
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']  # Blue, Orange, Green

# Create a horizontal bar chart
plt.figure(figsize=(8, 6))
bars = plt.barh(top_3_avg_pay_sorted['county_name'], top_3_avg_pay_sorted['avg_annual_pay'], color=colors)

# Invert y-axis to have the highest at the top
plt.gca().invert_yaxis()

# Add labels and title
plt.xlabel("Average Annual Pay")
plt.ylabel("County")
plt.title("Top 3 Kansas Counties by Average Annual Pay in Manufacturing")

# Add annotations using plt.bar_label()
plt.bar_label(bars)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Rank 3 out of (sedgwick,buttler,cowley) counties**

# %% [markdown]
# Counties by area_fips code
#
# *   Kansas (Statewide) → 20000
# *   Sedgwick County, KS → 20173
#
# *   Butler County, KS → 20015
# *   Cowley County, KS → 20035

# %%
# List of area_fips codes for the counties and state
area_fips_codes = ['20000', '20173', '20015', '20035']

# Filter the DataFrame for the specified counties and state
filtered_df = df[df['area_fips'].astype(str).isin(area_fips_codes)]

# Display the filtered DataFrame
filtered_df[['area_fips','avg_annual_pay']]
# Out:
#      area_fips  avg_annual_pay
# 961      20000           70906
# 969      20015           86068
# 979      20035           62179
# 1045     20173           78929

# %%
# Create a dictionary to map area_fips codes to county names
county_names = {

    '20173': 'Sedgwick County',
    '20015': 'Butler County',
    '20035': 'Cowley County'
}

# Create a new column with county names
filtered_df['county_name'] = filtered_df['area_fips'].astype(str).map(county_names)

# Sort the DataFrame by average annual pay in descending order
ranked_df = filtered_df.sort_values('avg_annual_pay', ascending=False)

# Create the bar plot
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
barplot = sns.barplot(x='county_name', y='avg_annual_pay', data=ranked_df, palette="viridis")

# Add annotations on top of each bar
for index, row in ranked_df.iterrows():
    barplot.annotate(
        f"${row['avg_annual_pay']:,.0f}",  # Format as currency
        xy=(row['county_name'], row['avg_annual_pay']),
        xytext=(0, 5),  # Offset the text slightly above the bar
        textcoords='offset points',
        ha='center',
        va='bottom',
        fontsize=10,
        fontweight='bold'
    )

# Customize plot
plt.title('Ranking of the Kansas Counties-sedgwick,buttler,cowley by Average Annual Pay in Manufacturing')
plt.xlabel('County')
plt.ylabel('Average Annual Pay')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a dictionary to map area_fips codes to county names
county_names = {
    '20000': 'Kansas (Statewide)',
    '20173': 'Sedgwick County',
    '20015': 'Butler County',
    '20035': 'Cowley County'
}

# Create a new column with county names
filtered_df['county_name'] = filtered_df['area_fips'].astype(str).map(county_names)

# Separate Kansas (Statewide) for comparison
statewide_df = filtered_df[filtered_df['county_name'] == 'Kansas (Statewide)']
county_df = filtered_df[filtered_df['county_name'] != 'Kansas (Statewide)']

# Sort the DataFrame by average annual pay in descending order (only counties)
ranked_df = county_df.sort_values('avg_annual_pay', ascending=False)

# Create the bar plot for counties
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
barplot = sns.barplot(x='county_name', y='avg_annual_pay', data=ranked_df, palette="viridis")

# Add annotations on top of each county bar
for index, row in ranked_df.iterrows():
    barplot.annotate(
        f"${row['avg_annual_pay']:,.0f}",  # Format as currency
        xy=(row['county_name'], row['avg_annual_pay']),
        xytext=(0, 5),  # Offset the text slightly above the bar
        textcoords='offset points',
        ha='center',
        va='bottom',
        fontsize=10,
        fontweight='bold'
    )

# Add Kansas (Statewide) average as a horizontal line for comparison
if not statewide_df.empty:
    statewide_pay = statewide_df['avg_annual_pay'].values[0]
    plt.axhline(y=statewide_pay, color='red', linestyle='--', label=f'Kansas Statewide: ${statewide_pay:,.0f}')
    plt.legend()

# Customize plot
plt.title('Comparison of Kansas Counties (Sedgwick, Butler, Cowley) with Statewide Average Annual Pay in Manufacturing')
plt.xlabel('County')
plt.ylabel('Average Annual Pay')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Show the plot
plt.show()

# %%
filtered_df[['area_fips','annual_avg_emplvl']]
# Out:
#      area_fips  annual_avg_emplvl
# 961      20000             173226
# 969      20015               1944
# 979      20035               3846
# 1045     20173              46083

# %% [markdown]
# # **Kansas-manufacturing-private_ownership-Employment-2014 t0 2023**

# %%
df_2014  = pd.read_csv('/content/kansas_2014.csv')
df_2015  = pd.read_csv('/content/kansas_2015.csv')
df_2016  = pd.read_csv('/content/kansas_2016.csv')
df_2017  = pd.read_csv('/content/kansas_2017.csv')
df_2018  = pd.read_csv('/content/kansas_2018.csv')
df_2019  = pd.read_csv('/content/kansas_2019.csv')
df_2020  = pd.read_csv('/content/kansas_2020.csv')
df_2021  = pd.read_csv('/content/kansas_2021.csv')
df_2022  = pd.read_csv('/content/kansas_2022.csv')
df_2023  = pd.read_csv('/content/kansas_2023.csv')

# %%
df_2014.drop_duplicates(inplace=True)
df_2015.drop_duplicates(inplace=True)
df_2016.drop_duplicates(inplace=True)
df_2017.drop_duplicates(inplace=True)
df_2018.drop_duplicates(inplace=True)
df_2019.drop_duplicates(inplace=True)
df_2020.drop_duplicates(inplace=True)
df_2021.drop_duplicates(inplace=True)
df_2022.drop_duplicates(inplace=True)
df_2023.drop_duplicates(inplace=True)

# %%
df_2023.dtypes
# Out:
# area_fips                                int64
# own_code                                 int64
# industry_code                           object
# agglvl_code                              int64
# size_code                                int64
# year                                     int64
# qtr                                     object
# disclosure_code                         object
# area_title                              object
# own_title                               object
# industry_title                          object
# agglvl_title                            object
# size_title                              object
# annual_avg_estabs_count                  int64
# annual_avg_emplvl                        int64
# total_annual_wages                       int64
# taxable_annual_wages                     int64
# annual_contributions                     int64
# annual_avg_wkly_wage                     int64
# avg_annual_pay                           int64
# ...

# %%
df_2023.head()
# Out:
#    area_fips  own_code industry_code  agglvl_code  size_code  year qtr  \
# 0      20000         0            10           50          0  2023   A
# 1      20000         1            10           51          0  2023   A
# 2      20000         1           102           52          0  2023   A
# 3      20000         1          1021           53          0  2023   A
# 4      20000         1          1022           53          0  2023   A
#
#   disclosure_code           area_title           own_title  ...  \
# 0             NaN  Kansas -- Statewide       Total Covered  ...
# 1             NaN  Kansas -- Statewide  Federal Government  ...
# 2             NaN  Kansas -- Statewide  Federal Government  ...
# 3             NaN  Kansas -- Statewide  Federal Government  ...
# 4             NaN  Kansas -- Statewide  Federal Government  ...
#
#   oty_total_annual_wages_chg oty_total_annual_wages_pct_chg  \
# 0                 4621380462                            5.9
# ...

# %%
# Convert industry_code to numeric and handle non-numeric values
dfs = [df_2014, df_2015, df_2016, df_2017, df_2018,
       df_2019, df_2020, df_2021, df_2022, df_2023]

# Apply filtering with type conversion
for i, df in enumerate(dfs, start=2014):
    df['industry_code'] = pd.to_numeric(df['industry_code'], errors='coerce')  # Convert to numeric
    df['own_code'] = pd.to_numeric(df['own_code'], errors='coerce')           # Ensure own_code is numeric

# filter each DataFrame
df_2014_filtered = df_2014[(df_2014['own_code'] == 5) & (df_2014['industry_code'] == 1013)][['year', 'area_title', 'annual_avg_emplvl']]
df_2015_filtered = df_2015[(df_2015['own_code'] == 5) & (df_2015['industry_code'] == 1013)][['year', 'area_title', 'annual_avg_emplvl']]
df_2016_filtered = df_2016[(df_2016['own_code'] == 5) & (df_2016['industry_code'] == 1013)][['year', 'area_title', 'annual_avg_emplvl']]
df_2017_filtered = df_2017[(df_2017['own_code'] == 5) & (df_2017['industry_code'] == 1013)][['year', 'area_title', 'annual_avg_emplvl']]
df_2018_filtered = df_2018[(df_2018['own_code'] == 5) & (df_2018['industry_code'] == 1013)][['year', 'area_title', 'annual_avg_emplvl']]
df_2019_filtered = df_2019[(df_2019['own_code'] == 5) & (df_2019['industry_code'] == 1013)][['year', 'area_title', 'annual_avg_emplvl']]
df_2020_filtered = df_2020[(df_2020['own_code'] == 5) & (df_2020['industry_code'] == 1013)][['year', 'area_title', 'annual_avg_emplvl']]
df_2021_filtered = df_2021[(df_2021['own_code'] == 5) & (df_2021['industry_code'] == 1013)][['year', 'area_title', 'annual_avg_emplvl']]
df_2022_filtered = df_2022[(df_2022['own_code'] == 5) & (df_2022['industry_code'] == 1013)][['year', 'area_title', 'annual_avg_emplvl']]
df_2023_filtered = df_2023[(df_2023['own_code'] == 5) & (df_2023['industry_code'] == 1013)][['year', 'area_title', 'annual_avg_emplvl']]

# %%
#  print all filtered data frames

print(df_2014_filtered)
print(df_2015_filtered)
print(df_2016_filtered)
print(df_2017_filtered)
print(df_2018_filtered)
print(df_2019_filtered)
print(df_2020_filtered)
print(df_2021_filtered)
print(df_2022_filtered)
print(df_2023_filtered)
# Out:
#      year           area_title  annual_avg_emplvl
# 638  2014  Kansas -- Statewide             162391
#      year           area_title  annual_avg_emplvl
# 632  2015  Kansas -- Statewide             161244
#      year           area_title  annual_avg_emplvl
# 639  2016  Kansas -- Statewide             160301
#      year           area_title  annual_avg_emplvl
# 642  2017  Kansas -- Statewide             161517
#      year           area_title  annual_avg_emplvl
# 649  2018  Kansas -- Statewide             165056
#      year           area_title  annual_avg_emplvl
# 641  2019  Kansas -- Statewide             167196
#      year           area_title  annual_avg_emplvl
# 644  2020  Kansas -- Statewide             158784
#      year           area_title  annual_avg_emplvl
# 645  2021  Kansas -- Statewide             160731
#      year           area_title  annual_avg_emplvl
# 661  2022  Kansas -- Statewide             169071
#      year           area_title  annual_avg_emplvl
# ...

# %%
# Concatenate the filtered DataFrames
frames = [df_2014_filtered, df_2015_filtered, df_2016_filtered, df_2017_filtered,
          df_2018_filtered, df_2019_filtered, df_2020_filtered, df_2021_filtered,
          df_2022_filtered, df_2023_filtered]

Annual_emp_avg = pd.concat(frames)

# Display the result
Annual_emp_avg
# Out:
#      year           area_title  annual_avg_emplvl
# 638  2014  Kansas -- Statewide             162391
# 632  2015  Kansas -- Statewide             161244
# 639  2016  Kansas -- Statewide             160301
# 642  2017  Kansas -- Statewide             161517
# 649  2018  Kansas -- Statewide             165056
# 641  2019  Kansas -- Statewide             167196
# 644  2020  Kansas -- Statewide             158784
# 645  2021  Kansas -- Statewide             160731
# 661  2022  Kansas -- Statewide             169071
# 649  2023  Kansas -- Statewide             173226

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='annual_avg_emplvl', data=Annual_emp_avg, marker='o')

# Annotate each data point with its value
for x, y in zip(Annual_emp_avg['year'], Annual_emp_avg['annual_avg_emplvl']):
    plt.annotate(f'{y:.0f}',  # Format the value as needed
                 (x, y),
                 textcoords="offset points",
                 xytext=(0, 10),
                 ha='center')


plt.title('Trend of Annual Average Employment Level in Manufacturing (2014-2023)')
plt.xlabel('Year')
plt.ylabel('Annual Average Employment Level')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set Seaborn style for aesthetics
sns.set_style("whitegrid")

# Create the figure
plt.figure(figsize=(12, 6))

# Line plot with markers
sns.lineplot(
    x='year',
    y='annual_avg_emplvl',
    data=Annual_emp_avg,
    marker='o',
    color='royalblue',
    linewidth=2.5
)

# Annotate each data point with its value
for x, y in zip(Annual_emp_avg['year'], Annual_emp_avg['annual_avg_emplvl']):
    plt.annotate(f'{y:.0f}',
                 (x, y),
                 textcoords="offset points",
                 xytext=(0, 10),
                 fontsize=12,
                 ha='center')

# Add title and labels
plt.title('Trend of Annual Average Employment Level in Manufacturing (2014-2023)', fontsize=14, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Annual Average Employment Level', fontsize=12)

# Ensure all years are displayed on the x-axis
plt.xticks(np.arange(2014, 2024, 1))

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Apply tight layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %%
Annual_emp_avg.head()
# Out:
#      year           area_title  annual_avg_emplvl
# 638  2014  Kansas -- Statewide             162391
# 632  2015  Kansas -- Statewide             161244
# 639  2016  Kansas -- Statewide             160301
# 642  2017  Kansas -- Statewide             161517
# 649  2018  Kansas -- Statewide             165056

# %%
# Calculate the monthly average employment level
Annual_emp_avg['monthly_avg_emplvl'] = Annual_emp_avg['annual_avg_emplvl'] / 12

# %%
Annual_emp_avg.head()
# Out:
#      year           area_title  annual_avg_emplvl  monthly_avg_emplvl
# 638  2014  Kansas -- Statewide             162391        13532.583333
# 632  2015  Kansas -- Statewide             161244        13437.000000
# 639  2016  Kansas -- Statewide             160301        13358.416667
# 642  2017  Kansas -- Statewide             161517        13459.750000
# 649  2018  Kansas -- Statewide             165056        13754.666667

# %%
plt.figure(figsize=(12, 6))
plt.plot(Annual_emp_avg['year'], Annual_emp_avg['monthly_avg_emplvl'], marker='o', linestyle='-')


# Annotate each data point with its value
for x, y in zip(Annual_emp_avg['year'], Annual_emp_avg['monthly_avg_emplvl']):
    plt.annotate(f'{y:.2f}',  # Format the value as needed
                 (x, y),
                 textcoords="offset points",
                 xytext=(0, 10),
                 ha='center')

plt.title('Trend of Monthly Average Employment Level in Manufacturing (2014-2023)')
plt.xlabel('Year')
plt.ylabel('Monthly Average Employment Level')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set figure size
plt.figure(figsize=(12, 6))

# Plot the line chart with markers
plt.plot(Annual_emp_avg['year'], Annual_emp_avg['monthly_avg_emplvl'], marker='o', linestyle='-', color='teal', linewidth=2)

# Annotate each data point with its value
for x, y in zip(Annual_emp_avg['year'], Annual_emp_avg['monthly_avg_emplvl']):
    plt.annotate(f'{y:.2f}',
                 (x, y),
                 textcoords="offset points",
                 xytext=(0, 10),
                 fontsize=12,
                 ha='center')

# Title and labels
plt.title(' Trend of Monthly Average Employment Level in Manufacturing (2014-2023)', fontsize=14, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Monthly Average Employment Level', fontsize=12)

# Ensure all years show up on the x-axis
plt.xticks(np.arange(2014, 2024, 1))

# Grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
